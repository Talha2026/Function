# %% [markdown]
# # Function Assignment
# Q1. What is the difference between a function and a method in Python?
# -  Function: A block of reusable code that performs a task, defined with def.
#
# - Method: A function associated with an object (called on objects).
# - Example:

# %%
def greet():
    return "Hello"
print(greet())   # Function call

text = "hello"
print(text.upper())  # Method call on string object

# %% [markdown]
# Q2. Explain the concept of function arguments and parameters in Python.
# -   Parameters: Variables defined in the function definition.
#
# -   Arguments: Actual values passed when calling the function.
# -   Example:

# %%
def add(a, b):  # a, b are parameters
    return a + b

print(add(5, 10))  # 5, 10 are arguments

# %% [markdown]
# Q3. What are the different ways to define and call a function in Python?
# -   Regular function
#
# -    Lambda function
#
# -  Built-in function
# -  Example:

# %%
# Regular function
def square(x):
    return x * x
print(square(4))

# Lambda function
f = lambda x: x * x
print(f(4))

# Using built-in sum()
print(sum([1, 2, 3]))

# %% [markdown]
# Q4. What is the purpose of the `return` statement in a Python function?
# -  Used to send the result back to the caller and exit the function
# -  Example:

# %%
def multiply(a, b):
    return a * b

result = multiply(3, 4)
print(result)  # 12

# %% [markdown]
# Q5. What are iterators in Python and how do they differ from iterables?
# -  Iterable: An object that can return an iterator (e.g., list, tuple).
#
# - Iterator: An object with __next__() method that returns elements one by one.

# %%
nums = [1, 2, 3]   # Iterable
it = iter(nums)    # Iterator
print(next(it))    # 1
print(next(it))    # 2

# %% [markdown]
# Q6. Explain the concept of generators in Python and how they are defined.
# -  Functions that use yield instead of return.
#
# - They produce values one at a time (lazy evaluation).
#  - Example:

# %%
def gen_nums():
    yield 1
    yield 2
    yield 3

for n in gen_nums():
    print(n)

# %% [markdown]
# Q7. What are the advantages of using generators over regular functions?
# -   Memory efficient (don’t store all values).
#
# -  Faster for large datasets.
#
# -  Useful in streaming data.
#
# Example: Iterating over a billion numbers with yield instead of storing them

# %% [markdown]
# Q8. What is a lambda function in Python and when is it typically used?
# -  Anonymous (no name) small function.
#
# -  Used for short, one-line functions.
# -  Example:
#
#      square = lambda x: x**2
#
#     print(square(5))  # 25

# %% [markdown]
# Q9. Explain the purpose and usage of the `map()` function in Python
# -  Applies a function to each element of an iterable.
#
# -  Example:
#  - nums = [1, 2, 3]
# -  squared = map(lambda x: x**2, nums)
# -  print(list(squared))  # [1, 4, 9]

# %% [markdown]
# Q10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
# -   map() → Applies function to all elements.
#
# -  filter() → Filters elements based on condition.
#
# -  reduce() → Reduces iterable to a single value by cumulative operation.
# - Example:

# %%
from functools import reduce

nums = [1, 2, 3, 4]

print(list(map(lambda x: x*2, nums)))       # [2, 4, 6, 8]
print(list(filter(lambda x: x%2==0, nums))) # [2, 4]
print(reduce(lambda x,y: x+y, nums))        # 10

# %% [markdown]
# Q11. Using pen & Paper write the internal mechanism for sum operation using reduce function on this given
# list:[47,11,42,13];
#  -   We use:

# %%
from functools import reduce
reduce(lambda x, y: x + y, [47, 11, 42, 13])

# %% [markdown]
# Step-by-step (pen & paper style):
#
# First two elements → 47 + 11 = 58
# -  List becomes: [58, 42, 13]
#
# Next → 58 + 42 = 100
# -   List becomes: [100, 13]
#
# Next → 100 + 13 = 113
# -  Final Result = 113

# %% [markdown]
# #Practical Questions
# Q1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.

# %%
def sum_even(nums):
    return sum(x for x in nums if x % 2 == 0)

print(sum_even([1, 2, 3, 4, 6, 7]))  # Output: 12

# %% [markdown]
# Q2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(s):
    return s[::-1]

print(reverse_string("Python"))  # nohtyP

# %% [markdown]
# Q3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.

# %%
def square_list(nums):
    return [x**2 for x in nums]

print(square_list([1, 2, 3, 4]))  # [1, 4, 9, 16]

# %% [markdown]
# Q4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %% [markdown]
# def is_prime(n):
#     if n < 2:
#         return False
#     for i in range(2, int(n**0.5)+1):
#         if n % i == 0:
#             return False
#     return True
#
# print(is_prime(17))  # True
# print(is_prime(100)) # False

# %% [markdown]
# Q5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.

# %%
class Fibonacci:
    def __init__(self, n):
        self.n = n
        self.a, self.b, self.count = 0, 1, 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.n:
            raise StopIteration
        val = self.a
        self.a, self.b = self.b, self.a + self.b
        self.count += 1
        return val

for num in Fibonacci(7):
    print(num, end=" ")  # 0 1 1 2 3 5 8

# %% [markdown]
# Q6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(n):
    for i in range(n+1):
        yield 2**i

print(list(powers_of_two(5)))  # [1, 2, 4, 8, 16, 32]

# %% [markdown]
# Q7. Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_file(filename):
    with open(filename, "r") as f:
        for line in f:
            yield line.strip()

# Example (assuming test.txt exists)
# for line in read_file("test.txt"):
#     print(line)

# %% [markdown]
# Q8.  Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
data = [(1, 4), (2, 1), (3, 3)]
sorted_data = sorted(data, key=lambda x: x[1])
print(sorted_data)  # [(2, 1), (3, 3), (1, 4)]

# %% [markdown]
# Q9.Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
temps_c = [0, 20, 37, 100]
temps_f = list(map(lambda c: (c * 9/5) + 32, temps_c))
print(temps_f)  # [32.0, 68.0, 98.6, 212.0]

# %% [markdown]
# Q10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
def remove_vowels(s):
    return "".join(filter(lambda ch: ch.lower() not in "aeiou", s))

print(remove_vowels("Programming"))  # Prgrmmng

# %% [markdown]
# Q11. Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
#
#
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.
#
# Write a Python program using lambda and map

# %%
books = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

# %%
result = list(
    map(
        lambda x: (x[0], x[2] * x[3] + (10 if x[2] * x[3] < 100 else 0)),
        books
    )
)

print(result)

# %% [markdown]
# Output

# %%
[(34587, 163.8), (98762, 284.0), (77226, 108.85), (88112, 84.97 + 10)]
[(34587, 163.8), (98762, 284.0), (77226, 108.85), (88112, 94.97)]
